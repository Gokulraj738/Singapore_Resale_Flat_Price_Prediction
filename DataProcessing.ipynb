# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
from datetime import datetime
import plotly as px
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv("C:/Users/Hp/Downloads/ResaleFlatPricesBasedonApprovalDate19901999.csv")

# %%
df1.head(3)
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
#
#    floor_area_sqm flat_model  lease_commence_date  resale_price
# 0            31.0   IMPROVED                 1977          9000
# 1            31.0   IMPROVED                 1977          6000
# 2            31.0   IMPROVED                 1977          8000

# %%
df1.shape
# Out:
# (287196, 10)

# %%
df1.isnull().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# dtype: int64

# %%
df2=pd.read_csv("C:/Users/Hp/Downloads/ResaleFlatPricesBasedonApprovalDate2000Feb2012.csv")

# %%
df2.isnull().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# dtype: int64

# %%
df2.head(3)
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  2000-01  ANG MO KIO    3 ROOM   170  ANG MO KIO AVE 4     07 TO 09
# 1  2000-01  ANG MO KIO    3 ROOM   174  ANG MO KIO AVE 4     04 TO 06
# 2  2000-01  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price
# 0            69.0        Improved                 1986      147000.0
# 1            61.0        Improved                 1986      144000.0
# 2            73.0  New Generation                 1976      159000.0

# %%
df3=pd.read_csv("C:/Users/Hp/Downloads/ResaleFlatPricesBasedonRegistrationDateFromMar2012toDec2014.csv")

# %%
df3.head(3)
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  2012-03  ANG MO KIO    2 ROOM   172  ANG MO KIO AVE 4     06 TO 10
# 1  2012-03  ANG MO KIO    2 ROOM   510  ANG MO KIO AVE 8     01 TO 05
# 2  2012-03  ANG MO KIO    3 ROOM   610  ANG MO KIO AVE 4     06 TO 10
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price
# 0            45.0        Improved                 1986      250000.0
# 1            44.0        Improved                 1980      265000.0
# 2            68.0  New Generation                 1980      315000.0

# %%
df3.isnull().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# dtype: int64

# %%
df4=pd.read_csv("C:/Users/Hp/Downloads/ResaleFlatPricesBasedonRegistrationDateFromJan2015toDec2016.csv")

# %%
df4.head(3)
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            60.0        Improved                 1986               70
# 1            68.0  New Generation                 1981               65
# 2            69.0  New Generation                 1980               64
#
#    resale_price
# 0      255000.0
# 1      275000.0
# 2      285000.0

# %%
df4['remaining_lease']
# Out:
# 0        70
# 1        65
# 2        64
# 3        63
# 4        64
#          ..
# 37148    82
# 37149    69
# 37150    74
# 37151    70
# 37152    70
# Name: remaining_lease, Length: 37153, dtype: int64

# %%
df4.isnull().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# remaining_lease        0
# resale_price           0
# dtype: int64

# %%
df5=pd.read_csv("C:/Users/Hp/Downloads/ResaleflatpricesbasedonregistrationdatefromJan2017onwards.csv")

# %%
df5.head(3)
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date     remaining_lease  \
# 0            44.0        Improved                 1979  61 years 04 months
# 1            67.0  New Generation                 1978  60 years 07 months
# 2            67.0  New Generation                 1980  62 years 05 months
#
#    resale_price
# 0      232000.0
# 1      250000.0
# 2      262000.0

# %%
df5.isnull().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# remaining_lease        0
# resale_price           0
# dtype: int64

# %%
df = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)

# %%
df.head(3)
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
#
#    floor_area_sqm flat_model  lease_commence_date  resale_price  \
# 0            31.0   IMPROVED                 1977        9000.0
# 1            31.0   IMPROVED                 1977        6000.0
# 2            31.0   IMPROVED                 1977        8000.0
#
#   remaining_lease
# 0             NaN
# 1             NaN
# 2             NaN

# %%
df['month'] = pd.to_datetime(df['month'], format='%Y-%m')

# %%
df.head(3)
# Out:
#        month        town flat_type block       street_name storey_range  \
# 0 1990-01-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1 1990-01-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2 1990-01-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
#
#    floor_area_sqm flat_model  lease_commence_date  resale_price  \
# 0            31.0   IMPROVED                 1977        9000.0
# 1            31.0   IMPROVED                 1977        6000.0
# 2            31.0   IMPROVED                 1977        8000.0
#
#   remaining_lease
# 0             NaN
# 1             NaN
# 2             NaN

# %%
df['year'] = df['month'].dt.year
df['month'] = df['month'].dt.month

# %%
df.head(3)
# Out:
#    month        town flat_type block       street_name storey_range  \
# 0      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
#
#    floor_area_sqm flat_model  lease_commence_date  resale_price  \
# 0            31.0   IMPROVED                 1977        9000.0
# 1            31.0   IMPROVED                 1977        6000.0
# 2            31.0   IMPROVED                 1977        8000.0
#
#   remaining_lease  year
# 0             NaN  1990
# 1             NaN  1990
# 2             NaN  1990

# %%
df.tail(3)
# Out:
#         month    town  flat_type block   street_name storey_range  \
# 930932      7  YISHUN  EXECUTIVE   277  YISHUN ST 22     01 TO 03
# 930933      7  YISHUN  EXECUTIVE   277  YISHUN ST 22     04 TO 06
# 930934      7  YISHUN  EXECUTIVE   277  YISHUN ST 22     01 TO 03
#
#         floor_area_sqm  flat_model  lease_commence_date  resale_price  \
# 930932           146.0  Maisonette                 1985      770000.0
# 930933           146.0  Maisonette                 1985      800000.0
# 930934           146.0  Maisonette                 1985      775000.0
#
#            remaining_lease  year
# 930932  60 years 03 months  2024
# 930933  60 years 02 months  2024
# 930934  60 years 02 months  2024

# %%
df.dtypes
# Out:
# month                    int32
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# remaining_lease         object
# year                     int32
# dtype: object

# %%
df['lease_commence_date'] = pd.to_datetime(df['lease_commence_date'], format='%Y')

# %%
df.dtypes
# Out:
# month                           int32
# town                           object
# flat_type                      object
# block                          object
# street_name                    object
# storey_range                   object
# floor_area_sqm                float64
# flat_model                     object
# lease_commence_date    datetime64[ns]
# resale_price                  float64
# remaining_lease                object
# year                            int32
# dtype: object

# %%
df["address"]= df["block"]+" "+df["street_name"]

# %%
df.head(3)
# Out:
#    month        town flat_type block       street_name storey_range  \
# 0      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
#
#    floor_area_sqm flat_model lease_commence_date  resale_price  \
# 0            31.0   IMPROVED          1977-01-01        9000.0
# 1            31.0   IMPROVED          1977-01-01        6000.0
# 2            31.0   IMPROVED          1977-01-01        8000.0
#
#   remaining_lease  year               address
# 0             NaN  1990  309 ANG MO KIO AVE 1
# 1             NaN  1990  309 ANG MO KIO AVE 1
# 2             NaN  1990  309 ANG MO KIO AVE 1

# %%
df= df.drop(columns=["block","street_name"])

# %%
df["town"].unique()
# Out:
# array(['ANG MO KIO', 'BEDOK', 'BISHAN', 'BUKIT BATOK', 'BUKIT MERAH',
#        'BUKIT TIMAH', 'CENTRAL AREA', 'CHOA CHU KANG', 'CLEMENTI',
#        'GEYLANG', 'HOUGANG', 'JURONG EAST', 'JURONG WEST',
#        'KALLANG/WHAMPOA', 'MARINE PARADE', 'QUEENSTOWN', 'SENGKANG',
#        'SERANGOON', 'TAMPINES', 'TOA PAYOH', 'WOODLANDS', 'YISHUN',
#        'LIM CHU KANG', 'SEMBAWANG', 'BUKIT PANJANG', 'PASIR RIS',
#        'PUNGGOL'], dtype=object)

# %%
df['town'].nunique()
# Out:
# 27

# %%
df["flat_type"].unique()
# Out:
# array(['1 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', '2 ROOM', 'EXECUTIVE',
#        'MULTI GENERATION', 'MULTI-GENERATION'], dtype=object)

# %%
df["flat_type"].nunique()
# Out:
# 8

# %%
df["flat_model"].unique()
# Out:
# array(['IMPROVED', 'NEW GENERATION', 'MODEL A', 'STANDARD', 'SIMPLIFIED',
#        'MODEL A-MAISONETTE', 'APARTMENT', 'MAISONETTE', 'TERRACE',
#        '2-ROOM', 'IMPROVED-MAISONETTE', 'MULTI GENERATION',
#        'PREMIUM APARTMENT', 'Improved', 'New Generation', 'Model A',
#        'Standard', 'Apartment', 'Simplified', 'Model A-Maisonette',
#        'Maisonette', 'Multi Generation', 'Adjoined flat',
#        'Premium Apartment', 'Terrace', 'Improved-Maisonette',
#        'Premium Maisonette', '2-room', 'Model A2', 'DBSS', 'Type S1',
#        'Type S2', 'Premium Apartment Loft', '3Gen'], dtype=object)

# %%
df["flat_model"].nunique()
# Out:
# 34

# %%
df[["storey_start", "storey_end"]]= df["storey_range"].str.split(" TO ",expand=True)

# %%
df.drop(columns=["storey_range"],inplace= True)

# %%
df.isnull().sum()
# Out:
# month                       0
# town                        0
# flat_type                   0
# floor_area_sqm              0
# flat_model                  0
# lease_commence_date         0
# resale_price                0
# remaining_lease        709050
# year                        0
# address                     0
# storey_start                0
# storey_end                  0
# dtype: int64

# %%
df['remaining_lease']
# Out:
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#                  ...
# 930930     63 years 01 month
# 930931     63 years 01 month
# 930932    60 years 03 months
# 930933    60 years 02 months
# 930934    60 years 02 months
# Name: remaining_lease, Length: 930935, dtype: object

# %%
df['remaining_lease'] = df['remaining_lease'].fillna(0)

# %%
df['remaining_lease']
# Out:
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0
#                  ...
# 930930     63 years 01 month
# 930931     63 years 01 month
# 930932    60 years 03 months
# 930933    60 years 02 months
# 930934    60 years 02 months
# Name: remaining_lease, Length: 930935, dtype: object

# %%
df['remaining_years'] = df['remaining_lease'].str.extract(r'(\d+) years', expand=False).fillna(0).astype(int)
df['remaining_months'] = df['remaining_lease'].str.extract(r'(\d+) months', expand=False).fillna(0).astype(int)

# %%
df.head(3)
# Out:
#    month        town flat_type  floor_area_sqm flat_model lease_commence_date  \
# 0      1  ANG MO KIO    1 ROOM            31.0   IMPROVED          1977-01-01
# 1      1  ANG MO KIO    1 ROOM            31.0   IMPROVED          1977-01-01
# 2      1  ANG MO KIO    1 ROOM            31.0   IMPROVED          1977-01-01
#
#    resale_price remaining_lease  year               address storey_start  \
# 0        9000.0               0  1990  309 ANG MO KIO AVE 1           10
# 1        6000.0               0  1990  309 ANG MO KIO AVE 1           04
# 2        8000.0               0  1990  309 ANG MO KIO AVE 1           10
#
#   storey_end  remaining_years  remaining_months
# 0         12                0                 0
# 1         06                0                 0
# 2         12                0                 0

# %%
df.tail(3)
# Out:
#         month    town  flat_type  floor_area_sqm  flat_model  \
# 930932      7  YISHUN  EXECUTIVE           146.0  Maisonette
# 930933      7  YISHUN  EXECUTIVE           146.0  Maisonette
# 930934      7  YISHUN  EXECUTIVE           146.0  Maisonette
#
#        lease_commence_date  resale_price     remaining_lease  year  \
# 930932          1985-01-01      770000.0  60 years 03 months  2024
# 930933          1985-01-01      800000.0  60 years 02 months  2024
# 930934          1985-01-01      775000.0  60 years 02 months  2024
#
#                  address storey_start storey_end  remaining_years  \
# 930932  277 YISHUN ST 22           01         03               60
# 930933  277 YISHUN ST 22           04         06               60
# 930934  277 YISHUN ST 22           01         03               60
#
#         remaining_months
# 930932                 3
# 930933                 2
# 930934                 2

# %%
df.isnull().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# remaining_lease        0
# year                   0
# address                0
# storey_start           0
# storey_end             0
# remaining_years        0
# remaining_months       0
# dtype: int64

# %%
df.drop(columns=["remaining_lease"],inplace= True)

# %%
df.columns
# Out:
# Index(['month', 'town', 'flat_type', 'floor_area_sqm', 'flat_model',
#        'lease_commence_date', 'resale_price', 'year', 'address',
#        'storey_start', 'storey_end', 'remaining_years', 'remaining_months'],
#       dtype='object')

# %%
df[['year','month', 'town', 'flat_type', 'floor_area_sqm', 'flat_model', 'address', 
       'storey_start', 'storey_end', 'remaining_years','remaining_months',
       'lease_commence_date', 'resale_price']]
# Out:
#         year  month        town  flat_type  floor_area_sqm      flat_model  \
# 0       1990      1  ANG MO KIO     1 ROOM            31.0        IMPROVED
# 1       1990      1  ANG MO KIO     1 ROOM            31.0        IMPROVED
# 2       1990      1  ANG MO KIO     1 ROOM            31.0        IMPROVED
# 3       1990      1  ANG MO KIO     1 ROOM            31.0        IMPROVED
# 4       1990      1  ANG MO KIO     3 ROOM            73.0  NEW GENERATION
# ...      ...    ...         ...        ...             ...             ...
# 930930  2024      7      YISHUN  EXECUTIVE           146.0      Maisonette
# 930931  2024      7      YISHUN  EXECUTIVE           145.0       Apartment
# 930932  2024      7      YISHUN  EXECUTIVE           146.0      Maisonette
# 930933  2024      7      YISHUN  EXECUTIVE           146.0      Maisonette
# 930934  2024      7      YISHUN  EXECUTIVE           146.0      Maisonette
#
# ...

# %%
df.to_csv('SingaporeResaleFlatPrice.csv', index=False)

# %%
df.dtypes
# Out:
# month                           int32
# town                           object
# flat_type                      object
# floor_area_sqm                float64
# flat_model                     object
# lease_commence_date    datetime64[ns]
# resale_price                  float64
# year                            int32
# address                        object
# storey_start                   object
# storey_end                     object
# remaining_years                 int32
# remaining_months                int32
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder

# %%
df["town"]= LabelEncoder().fit_transform(df["town"])
df["flat_model"]= OrdinalEncoder().fit_transform(df[["flat_model"]])
df["flat_type"]= OrdinalEncoder().fit_transform(df[["flat_type"]])

# %%
df["town"].unique()
# Out:
# array([ 0,  1,  2,  3,  4,  6,  7,  8,  9, 10, 11, 12, 13, 14, 16, 19, 21,
#        22, 23, 24, 25, 26, 15, 20,  5, 17, 18])

# %%
df["flat_model"].unique()
# Out:
# array([ 7., 20., 12., 27., 26., 13.,  3., 11., 30.,  0.,  8., 14., 22.,
#         9., 21., 16., 29.,  5., 28., 17., 15., 19.,  4., 23., 31., 10.,
#        25.,  1., 18.,  6., 32., 33., 24.,  2.])

# %%
df["flat_type"].unique()
# Out:
# array([0., 2., 3., 4., 1., 5., 6., 7.])

# %%
df["address"]= LabelEncoder().fit_transform(df["address"])

# %%
df["address"].unique()
# Out:
# array([3837, 2375, 2288, ..., 5739,  613,  593])

# %%
df.to_csv('SingaporeResaleFlatPrice.csv', index=False)

# %%
dfcorr= df.corr()
plt.figure(figsize=(10,5))
sns.heatmap(dfcorr,annot= True, cmap="Greens", fmt=".2f")
plt.show()

# %%
df_data=pd.read_csv("C:/Users/Hp/Desktop/Singapore Resale Project/SingaporeResaleFlatPrice.csv")

# %%
df_data.head(2)
# Out:
#    month  town  flat_type  floor_area_sqm  flat_model lease_commence_date  \
# 0      1     0        0.0            31.0         7.0          1977-01-01
# 1      1     0        0.0            31.0         7.0          1977-01-01
#
#    resale_price  year  address  storey_start  storey_end  remaining_years  \
# 0        9000.0  1990     3837            10          12                0
# 1        6000.0  1990     3837             4           6                0
#
#    remaining_months
# 0                 0
# 1                 0

# %%
df_data.tail(2)
# Out:
#         month  town  flat_type  floor_area_sqm  flat_model  \
# 930933      7    26        5.0           146.0        15.0
# 930934      7    26        5.0           146.0        15.0
#
#        lease_commence_date  resale_price  year  address  storey_start  \
# 930933          1985-01-01      800000.0  2024     3380             4
# 930934          1985-01-01      775000.0  2024     3380             1
#
#         storey_end  remaining_years  remaining_months
# 930933           6               60                 2
# 930934           3               60                 2

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import warnings
warnings.filterwarnings("ignore")

# %%
df_data.duplicated().sum()
# Out:
# 1900

# %%
df_data_1=df_data.drop_duplicates()
df_data_1.reset_index(drop=True, inplace=True)

# %%
df_data_1.isnull().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# year                   0
# address                0
# storey_start           0
# storey_end             0
# remaining_years        0
# remaining_months       0
# dtype: int64

# %%
df_data_1.tail(3)
# Out:
#         month  town  flat_type  floor_area_sqm  flat_model  \
# 929032      7    26        5.0           146.0        15.0
# 929033      7    26        5.0           146.0        15.0
# 929034      7    26        5.0           146.0        15.0
#
#        lease_commence_date  resale_price  year  address  storey_start  \
# 929032          1985-01-01      770000.0  2024     3380             1
# 929033          1985-01-01      800000.0  2024     3380             4
# 929034          1985-01-01      775000.0  2024     3380             1
#
#         storey_end  remaining_years  remaining_months
# 929032           3               60                 3
# 929033           6               60                 2
# 929034           3               60                 2

# %%
df_data_2=df_data_1.drop(columns=["month", "address"])

# %%
df_data_2.tail(3)
# Out:
#         town  flat_type  floor_area_sqm  flat_model lease_commence_date  \
# 929032    26        5.0           146.0        15.0          1985-01-01
# 929033    26        5.0           146.0        15.0          1985-01-01
# 929034    26        5.0           146.0        15.0          1985-01-01
#
#         resale_price  year  storey_start  storey_end  remaining_years  \
# 929032      770000.0  2024             1           3               60
# 929033      800000.0  2024             4           6               60
# 929034      775000.0  2024             1           3               60
#
#         remaining_months
# 929032                 3
# 929033                 2
# 929034                 2

# %%
df_data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 929035 entries, 0 to 929034
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   town                 929035 non-null  int64
#  1   flat_type            929035 non-null  float64
#  2   floor_area_sqm       929035 non-null  float64
#  3   flat_model           929035 non-null  float64
#  4   lease_commence_date  929035 non-null  object
#  5   resale_price         929035 non-null  float64
#  6   year                 929035 non-null  int64
#  7   storey_start         929035 non-null  int64
#  8   storey_end           929035 non-null  int64
#  9   remaining_years      929035 non-null  int64
#  10  remaining_months     929035 non-null  int64
# dtypes: float64(4), int64(6), object(1)
# memory usage: 78.0+ MB

# %%
df_data_2['lease_commence_date'] = pd.to_datetime(df_data_2['lease_commence_date'])

# %%
df_data_2['lease_commence_year'] = df_data_2['lease_commence_date'].dt.year

# %%
current_year = pd.Timestamp.now().year
df_data_2['flat_age'] = current_year - df_data_2['lease_commence_year']

# %%
df_data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 929035 entries, 0 to 929034
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   town                 929035 non-null  int64
#  1   flat_type            929035 non-null  float64
#  2   floor_area_sqm       929035 non-null  float64
#  3   flat_model           929035 non-null  float64
#  4   lease_commence_date  929035 non-null  datetime64[ns]
#  5   resale_price         929035 non-null  float64
#  6   year                 929035 non-null  int64
#  7   storey_start         929035 non-null  int64
#  8   storey_end           929035 non-null  int64
#  9   remaining_years      929035 non-null  int64
#  10  remaining_months     929035 non-null  int64
#  11  lease_commence_year  929035 non-null  int32
#  12  flat_age             929035 non-null  int32
# dtypes: datetime64[ns](1), float64(4), int32(2), int64(6)
# memory usage: 85.1 MB

# %%
df_data_2.tail(3)
# Out:
#         town  flat_type  floor_area_sqm  flat_model lease_commence_date  \
# 929032    26        5.0           146.0        15.0          1985-01-01
# 929033    26        5.0           146.0        15.0          1985-01-01
# 929034    26        5.0           146.0        15.0          1985-01-01
#
#         resale_price  year  storey_start  storey_end  remaining_years  \
# 929032      770000.0  2024             1           3               60
# 929033      800000.0  2024             4           6               60
# 929034      775000.0  2024             1           3               60
#
#         remaining_months  lease_commence_year  flat_age
# 929032                 3                 1985        39
# 929033                 2                 1985        39
# 929034                 2                 1985        39

# %%
def plot(df,column):
  #distplot
  plt.figure(figsize=(15,4))
  plt.subplot(1,3,1)
  sns.distplot(df[column])
  plt.title("distplot for"+" "+column)

  #histogram plot

  plt.subplot(1,3,2)
  sns.histplot(df, x= column, kde= True, bins=30,color="salmon")
  plt.title("histogram plot for"+" "+column)

  #boxplot

  plt.subplot(1,3,3)

  sns.boxplot(df, x=column)
  plt.title("Box plot for"+" "+column)

for i in df_data_2.columns:
    plot(df_data_2,i)

# %%
df_data_2.describe().T
# Out:
#                         count                           mean  \
# town                 929035.0                      13.656416
# flat_type            929035.0                       3.015158
# floor_area_sqm       929035.0                      95.712681
# flat_model           929035.0                      15.715592
# lease_commence_date    929035  1988-04-27 16:14:10.978488320
# resale_price         929035.0                  322088.307961
# year                 929035.0                    2006.245449
# storey_start         929035.0                       6.686952
# storey_end           929035.0                       8.701659
# remaining_years      929035.0                      14.714686
# remaining_months     929035.0                       1.084704
# lease_commence_year  929035.0                    1988.321149
# flat_age             929035.0                      35.678851
#
#                                      min                  25%  \
# ...

# %%
df_data_3=df_data_2.copy()

# %%
df_data_3["storey_start"]= np.log(df_data_3["storey_start"])
df_data_3["storey_end"]= np.log(df_data_3["storey_end"])
df_data_3["resale_price"]= np.log(df_data_3["resale_price"])

# %%
skewed_columns=["storey_start","storey_end","resale_price"]
for i in skewed_columns:
    plot(df_data_3,i)

# %%
def outlier(df,column):
  q1= df[column].quantile(0.25)
  q3= df[column].quantile(0.75)

  iqr= q3-q1

  upper_threshold= q3 + (1.5*iqr)
  lower_threshold= q1 - (1.5*iqr)

  df[column]= df[column].clip(lower_threshold, upper_threshold)

# %%
outlier_columns=["floor_area_sqm","storey_start","storey_end","resale_price"]
for j in outlier_columns:
    outlier(df_data_3,j)


for k in outlier_columns:
    plot(df_data_3,k)

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df_data_3.corr(), annot= True, cmap="Greens", fmt="0.2f")
plt.show()

# %%
df_data_3.describe().T
# Out:
#                         count                           mean  \
# town                 929035.0                      13.656416
# flat_type            929035.0                       3.015158
# floor_area_sqm       929035.0                      95.684873
# flat_model           929035.0                      15.715592
# lease_commence_date    929035  1988-04-27 16:14:10.978488320
# resale_price         929035.0                      12.533661
# year                 929035.0                    2006.245449
# storey_start         929035.0                       1.576195
# storey_end           929035.0                       2.009891
# remaining_years      929035.0                      14.714686
# remaining_months     929035.0                       1.084704
# lease_commence_year  929035.0                    1988.321149
# flat_age             929035.0                      35.678851
#
#                                      min                  25%  \
# ...

# %%
df_data_3 = df_data_3.drop(columns=['lease_commence_date'])

# %%
df_data_3.describe().T
# Out:
#                         count         mean        std          min  \
# town                 929035.0    13.656416   8.794044     0.000000
# flat_type            929035.0     3.015158   0.949227     0.000000
# floor_area_sqm       929035.0    95.684873  25.717641    28.000000
# flat_model           929035.0    15.715592   6.664707     0.000000
# resale_price         929035.0    12.533661   0.578117    11.017019
# year                 929035.0  2006.245449   9.370087  1990.000000
# storey_start         929035.0     1.576195   0.900982     0.011858
# storey_end           929035.0     2.009891   0.569425     1.098612
# remaining_years      929035.0    14.714686  30.214320     0.000000
# remaining_months     929035.0     1.084704   2.701005     0.000000
# lease_commence_year  929035.0  1988.321149  10.702785  1966.000000
# flat_age             929035.0    35.678851  10.702785     4.000000
#
#                              25%          50%          75%          max
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
import pickle

# %%
def select_model(df, algorithm):

    x = df.drop(columns=["resale_price"])
    y = df["resale_price"]


    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)


    model = algorithm().fit(X_train, y_train)


    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)

    train_mse = mean_squared_error(y_train, y_pred_train)
    train_rmse = np.sqrt(train_mse)
    train_mae = mean_absolute_error(y_train, y_pred_train)
    train_r2 = r2_score(y_train, y_pred_train)

    test_mse = mean_squared_error(y_test, y_pred_test)
    test_rmse = np.sqrt(test_mse)
    test_mae = mean_absolute_error(y_test, y_pred_test)
    test_r2 = r2_score(y_test, y_pred_test)


    metrics_train = {
        "Data": "Train Data",
        "Model": algorithm.__name__,
        "R2_score": train_r2,
        "Mean_squared_error": train_mse,
        "Root_mean_squared_error": train_rmse,
        "Mean_absolute_error": train_mae
    }

    metrics_test = {
        "Data": "Test Data",
        "Model": algorithm.__name__,
        "R2_score": test_r2,
        "Mean_squared_error": test_mse,
        "Root_mean_squared_error": test_rmse,
        "Mean_absolute_error": test_mae
    }

    print(metrics_train)
    print(metrics_test)
    print("")

select_model(df_data_3, LinearRegression)
select_model(df_data_3, DecisionTreeRegressor)
select_model(df_data_3, RandomForestRegressor)
select_model(df_data_3, AdaBoostRegressor)
select_model(df_data_3, ExtraTreesRegressor)
select_model(df_data_3, GradientBoostingRegressor)
select_model(df_data_3, XGBRegressor)
# Out:
# {'Data': 'Train Data', 'Model': 'LinearRegression', 'R2_score': 0.7933682351920786, 'Mean_squared_error': 0.06910599901891676, 'Root_mean_squared_error': 0.2628801989859958, 'Mean_absolute_error': 0.20706949431826696}
# {'Data': 'Test Data', 'Model': 'LinearRegression', 'R2_score': 0.7934428425749573, 'Mean_squared_error': 0.06885219617063565, 'Root_mean_squared_error': 0.26239702012529725, 'Mean_absolute_error': 0.20677423308851275}
#
# {'Data': 'Train Data', 'Model': 'DecisionTreeRegressor', 'R2_score': 0.989682567273577, 'Mean_squared_error': 0.003450565775947912, 'Root_mean_squared_error': 0.058741516629619905, 'Mean_absolute_error': 0.03323850333040916}
# {'Data': 'Test Data', 'Model': 'DecisionTreeRegressor', 'R2_score': 0.9697030870593387, 'Mean_squared_error': 0.010098943164978785, 'Root_mean_squared_error': 0.10049349812290737, 'Mean_absolute_error': 0.06946845104225284}
#
# ...

# %%
x= df_data_3.drop(columns=["resale_price"])
y= df_data_3["resale_price"]

X_train, X_test, y_train, y_test= train_test_split(x,y, test_size=0.2, random_state=42)

model_1= RandomForestRegressor().fit(X_train,y_train)
y_pred= model_1.predict(X_test)

test_mse= mean_squared_error(y_test, y_pred)
test_rmse= np.sqrt(test_mse)
test_mae= mean_absolute_error(y_test, y_pred)
test_r2= r2_score(y_test, y_pred)

metrics_test={"Data": "Test Data",
        "Name":RandomForestRegressor.__name__,
        "R2_score":test_r2,
        "Mean_squared_error":test_mse,
        "Root_mean_squared_error":test_rmse,
        "Mean_absolute_error":test_mae
            }

print(metrics_test)
# Out:
# {'Data': 'Test Data', 'Name': 'RandomForestRegressor', 'R2_score': 0.976141289403438, 'Mean_squared_error': 0.007952881627784, 'Root_mean_squared_error': 0.08917893040278067, 'Mean_absolute_error': 0.062442323608490065}

# %%
df_data_3.iloc[10456]
# Out:
# town                      0.000000
# flat_type                 3.000000
# floor_area_sqm           92.000000
# flat_model               20.000000
# resale_price             11.512925
# year                   1990.000000
# storey_start              1.945910
# storey_end                2.197225
# remaining_years           0.000000
# remaining_months          0.000000
# lease_commence_year    1980.000000
# flat_age                 44.000000
# Name: 10456, dtype: float64

# %%
np.exp(11.512925)
# Out:
# 99999.95350298789

# %%
user_data = np.array([[0,3,92,20,1990,1,2,0,0,1980,44]])
y_pred_1 = model_1.predict(user_data)
y_pred_1[0]
# Out:
# 11.24545955649172

# %%
np.exp(11.251582775950226)
# Out:
# 77001.69980257077

# %%
with open("Singapore_Resale_Flat_Prices_Model_1.pkl","wb") as f:
  pickle.dump(model_1,f)

# %%
df_data_3.dtypes
# Out:
# town                     int64
# flat_type              float64
# floor_area_sqm         float64
# flat_model             float64
# resale_price           float64
# year                     int64
# storey_start           float64
# storey_end             float64
# remaining_years          int64
# remaining_months         int64
# lease_commence_year      int32
# flat_age                 int32
# dtype: object

# %%
from sklearn.ensemble import RandomForestRegressor

# Example of training a smaller RandomForest model
regg_model = RandomForestRegressor(n_estimators=100, max_depth=10, random_state=42)
regg_model.fit(X_train, y_train)

with open("Resale_Flat_Prices_Model_optimized.pkl", "wb") as f1:
    pickle.dump(regg_model, f1)

# %%
import joblib

# Example of saving a model with Joblib
joblib.dump(regg_model, "Resale_Flat_Prices_Model_optimized.joblib")
# Out:
# ['Resale_Flat_Prices_Model_optimized.joblib']
